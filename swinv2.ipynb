# %% [markdown]
# # wd-v1-4-swinv2-tagger

# %%
# clone the swinv2 model
# !git clone https://huggingface.co/SmilingWolf/wd-v1-4-swinv2-tagger-v2 ./tagger
# Out:
# fatal: destination path './tagger' already exists and is not an empty directory.

# %% [markdown]
# ## imports

# %%
import os

os.environ["KERAS_BACKEND"] = "torch"

import pandas as pd

import numpy as np
import torch
import torch.nn as nn
from keras.models import load_model, Model
from transformers import Swinv2Config, Swinv2ForImageClassification

# %%
config = Swinv2Config.from_pretrained("./swinv2-config")

# %% [markdown]
# ## Load and set labels

# %%
df = pd.read_csv("./tagger/selected_tags.csv")
df.head()
# Out:
#     tag_id          name  category    count
# 0  9999999       general         9   807858
# 1  9999998     sensitive         9  3771700
# 2  9999997  questionable         9   769899
# 3  9999996      explicit         9   560281
# 4   470575         1girl         0  4225150

# %%
def convert_tag_name(tag: str, category: int):
    if category == 0:
        return tag
    elif category == 4:
        return f"character:{tag}"
    elif category == 9:
        return f"rating:{tag}"

# %%
id2label = {
    i: convert_tag_name(tag, df["category"][i]) for i, tag in enumerate(df["name"])
}
id2label
# Out:
# {0: 'rating:general',
#  1: 'rating:sensitive',
#  2: 'rating:questionable',
#  3: 'rating:explicit',
#  4: '1girl',
#  5: 'solo',
#  6: 'long_hair',
#  7: 'breasts',
#  8: 'looking_at_viewer',
#  9: 'blush',
#  10: 'smile',
#  11: 'short_hair',
#  12: 'open_mouth',
#  13: 'bangs',
#  14: 'blue_eyes',
#  15: 'multiple_girls',
#  16: 'skirt',
#  17: 'blonde_hair',
#  18: 'large_breasts',
#  19: 'simple_background',
#  20: 'brown_hair',
#  21: 'shirt',
#  22: 'black_hair',
#  23: 'hair_ornament',
#  24: 'red_eyes',
#  25: 'thighhighs',
#  26: 'gloves',
#  27: 'long_sleeves',
#  28: '1boy',
#  29: 'hat',
#  30: 'white_background',
#  31: 'dress',
#  32: 'bow',
#  33: 'ribbon',
#  34: 'navel',
#  35: 'holding',
#  36: '2girls',
#  37: 'animal_ears',
#  38: 'cleavage',
#  39: 'hair_between_eyes',
#  40: 'bare_shoulders',
#  41: 'twintails',
#  42: 'brown_eyes',
#  43: 'jewelry',
#  44: 'medium_breasts',
#  45: 'sitting',
#  46: 'very_long_hair',
#  47: 'closed_mouth',
#  48: 'underwear',
#  49: 'nipples',
#  50: 'school_uniform',
#  51: 'green_eyes',
#  52: 'blue_hair',
#  53: 'standing',
#  54: 'purple_eyes',
#  55: 'collarbone',
#  56: 'panties',
#  57: 'jacket',
#  58: 'tail',
#  59: 'monochrome',
#  60: 'swimsuit',
#  61: 'full_body',
#  62: 'closed_eyes',
#  63: 'hair_ribbon',
#  64: 'yellow_eyes',
#  65: 'white_shirt',
#  66: 'upper_body',
#  67: 'ponytail',
#  68: 'weapon',
#  69: 'pink_hair',
#  70: 'purple_hair',
#  71: 'ass',
#  72: 'braid',
#  73: 'flower',
#  74: 'comic',
#  75: 'ahoge',
#  76: 'white_hair',
#  77: 'short_sleeves',
#  78: ':d',
#  79: 'hetero',
#  80: 'hair_bow',
#  81: 'greyscale',
#  82: 'grey_hair',
#  83: 'male_focus',
#  84: 'heart',
#  85: 'pantyhose',
#  86: 'sidelocks',
#  87: 'bikini',
#  88: 'thighs',
#  89: 'nude',
#  90: 'red_hair',
#  91: 'multicolored_hair',
#  92: 'cowboy_shot',
#  93: 'sweat',
#  94: 'pleated_skirt',
#  95: 'hairband',
#  96: 'earrings',
#  97: 'small_breasts',
#  98: 'boots',
#  99: 'outdoors',
#  100: 'lying',
#  101: 'censored',
#  102: 'frills',
#  103: 'parted_lips',
#  104: 'detached_sleeves',
#  105: 'one_eye_closed',
#  106: 'food',
#  107: 'japanese_clothes',
#  108: 'green_hair',
#  109: 'multiple_boys',
#  110: 'open_clothes',
#  111: 'wings',
#  112: 'necktie',
#  113: 'horns',
#  114: 'sky',
#  115: 'penis',
#  116: 'shoes',
#  117: 'glasses',
#  118: 'shorts',
#  119: 'barefoot',
#  120: 'teeth',
#  121: 'pussy',
#  122: 'serafuku',
#  123: 'sleeveless',
#  124: 'solo_focus',
#  125: 'alternate_costume',
#  126: 'choker',
#  127: 'day',
#  128: 'tongue',
#  129: 'pointy_ears',
#  130: 'black_gloves',
#  131: 'socks',
#  132: 'hairclip',
#  133: 'elbow_gloves',
#  134: 'fang',
#  135: 'midriff',
#  136: 'striped',
#  137: 'puffy_sleeves',
#  138: 'shiny',
#  139: 'collared_shirt',
#  140: 'belt',
#  141: 'looking_back',
#  142: 'pants',
#  143: 'sword',
#  144: 'artist_name',
#  145: 'black_thighhighs',
#  146: 'cloud',
#  147: 'indoors',
#  148: 'virtual_youtuber',
#  149: 'cat_ears',
#  150: 'tears',
#  151: 'white_gloves',
#  152: 'hand_up',
#  153: 'signature',
#  154: 'hair_flower',
#  155: 'dark_skin',
#  156: '3girls',
#  157: 'spread_legs',
#  158: 'cum',
#  159: 'hood',
#  160: '2boys',
#  161: 'sex',
#  162: 'tongue_out',
#  163: 'miniskirt',
#  164: 'wide_sleeves',
#  165: 'blunt_bangs',
#  166: 'on_back',
#  167: 'fingerless_gloves',
#  168: 'bowtie',
#  169: 'black_skirt',
#  170: 'medium_hair',
#  171: 'pink_eyes',
#  172: 'armpits',
#  173: 'sailor_collar',
#  174: 'kimono',
#  175: 'grey_background',
#  176: 'water',
#  177: 'necklace',
#  178: 'off_shoulder',
#  179: 'stomach',
#  180: 'bag',
#  181: 'hair_bun',
#  182: 'chibi',
#  183: 'clothes_lift',
#  184: 'twitter_username',
#  185: 'from_behind',
#  186: 'star_(symbol)',
#  187: 'scarf',
#  188: 'cape',
#  189: 'nail_polish',
#  190: 'black_footwear',
#  191: 'holding_weapon',
#  192: 'bra',
#  193: 'white_dress',
#  194: 'orange_hair',
#  195: 'yuri',
#  196: 'sweatdrop',
#  197: 'armor',
#  198: 'rabbit_ears',
#  199: 'mole',
#  200: 'white_panties',
#  201: 'hair_over_one_eye',
#  202: 'grin',
#  203: 'blurry',
#  204: 'huge_breasts',
#  205: 'looking_at_another',
#  206: ':o',
#  207: 'uniform',
#  208: 'black_eyes',
#  209: 'apron',
#  210: 'character_name',
#  211: 'vest',
#  212: 'black_dress',
#  213: 'mosaic_censoring',
#  214: 'arm_up',
#  215: 'vaginal',
#  216: 'red_bow',
#  217: 'high_heels',
#  218: 'shiny_hair',
#  219: 'twin_braids',
#  220: 'arms_up',
#  221: 'flat_chest',
#  222: 'side_ponytail',
#  223: 'collar',
#  224: 'bracelet',
#  225: 'feet',
#  226: 'covered_nipples',
#  227: 'from_side',
#  228: 'dated',
#  229: 'two-tone_hair',
#  230: 'aqua_eyes',
#  231: 'sweater',
#  232: 'speech_bubble',
#  233: 'white_thighhighs',
#  234: 'english_text',
#  235: 'leotard',
#  236: 'open_jacket',
#  237: 'official_alternate_costume',
#  238: 'red_ribbon',
#  239: 'dark-skinned_female',
#  240: 'two_side_up',
#  241: 'tree',
#  242: 'cup',
#  243: 'blue_sky',
#  244: 'sketch',
#  245: 'puffy_short_sleeves',
#  246: 'lips',
#  247: 'blue_skirt',
#  248: 'zettai_ryouiki',
#  249: 'streaked_hair',
#  250: 'coat',
#  251: 'black_jacket',
#  252: 'crop_top',
#  253: 'groin',
#  254: 'fingernails',
#  255: 'wet',
#  256: 'v-shaped_eyebrows',
#  257: 'cat_tail',
#  258: 'neckerchief',
#  259: 'orange_eyes',
#  260: 'animal_ear_fluff',
#  261: 'head_tilt',
#  262: 'see-through',
#  263: 'gradient',
#  264: 'hand_on_hip',
#  265: 'gun',
#  266: 'legs',
#  267: 'one-piece_swimsuit',
#  268: 'shiny_skin',
#  269: 'sleeves_past_wrists',
#  270: 'parted_bangs',
#  271: 'looking_to_the_side',
#  272: 'pillow',
#  273: 'wrist_cuffs',
#  274: 'grey_eyes',
#  275: 'torn_clothes',
#  276: 'book',
#  277: 'plaid',
#  278: 'black_pantyhose',
#  279: 'maid',
#  280: 'symbol-shaped_pupils',
#  281: 'hands_up',
#  282: 'sash',
#  283: 'fur_trim',
#  284: 'kneehighs',
#  285: 'maid_headdress',
#  286: 'military',
#  287: 'black_panties',
#  288: 'cosplay',
#  289: 'bare_arms',
#  290: 'petals',
#  291: 'pubic_hair',
#  292: 'black_shirt',
#  293: 'fox_ears',
#  294: 'loli',
#  295: 'gradient_background',
#  296: 'short_shorts',
#  297: 'ascot',
#  298: 'clothing_cutout',
#  299: 'completely_nude',
#  300: 'dutch_angle',
#  301: 'eyelashes',
#  302: 'bar_censor',
#  303: 'mole_under_eye',
#  304: 'pokemon_(creature)',
#  305: 'no_humans',
#  306: 'bare_legs',
#  307: 'window',
#  308: 'open_shirt',
#  309: 'sparkle',
#  310: 'dress_shirt',
#  311: 'kneeling',
#  312: 'sleeveless_shirt',
#  313: 'single_braid',
#  314: 'v',
#  315: 'black_headwear',
#  316: 'strapless',
#  317: '4girls',
#  318: 'bell',
#  319: 'hug',
#  320: 'no_bra',
#  321: 'saliva',
#  322: 'double_bun',
#  323: 'black_ribbon',
#  324: 'uncensored',
#  325: 'aqua_hair',
#  326: 'bodysuit',
#  327: 'blood',
#  328: 'bed',
#  329: 'hoodie',
#  330: 'military_uniform',
#  331: 'sideboob',
#  332: 'black_bow',
#  333: 'covered_navel',
#  334: 'tattoo',
#  335: 'gradient_hair',
#  336: 'skindentation',
#  337: 'neck_ribbon',
#  338: 'pussy_juice',
#  339: 'profile',
#  340: 'makeup',
#  341: 'thigh_strap',
#  342: 'leaning_forward',
#  343: 'multiple_views',
#  344: '4koma',
#  345: 'capelet',
#  346: 'mask',
#  347: 'muscular',
#  348: 'anus',
#  349: 'no_panties',
#  350: 'witch_hat',
#  351: 'detached_collar',
#  352: 'toes',
#  353: ':3',
#  354: 'copyright_name',
#  355: 'alternate_hairstyle',
#  356: 'underboob',
#  357: 'night',
#  358: 'buttons',
#  359: 'floating_hair',
#  360: 'fruit',
#  361: 'sleeveless_dress',
#  362: 'depth_of_field',
#  363: 'blurry_background',
#  364: 'feet_out_of_frame',
#  365: 'headband',
#  366: 'fake_animal_ears',
#  367: '^_^',
#  368: 'blue_dress',
#  369: 'cameltoe',
#  370: 'cum_in_pussy',
#  371: 'fox_tail',
#  372: 'swept_bangs',
#  373: 'shadow',
#  374: 'black_bikini',
#  375: 'red_skirt',
#  376: 'nose_blush',
#  377: 'bottomless',
#  378: 'glowing',
#  379: 'side-tie_bikini_bottom',
#  380: 'rose',
#  381: 'bed_sheet',
#  382: 'colored_skin',
#  383: 'turtleneck',
#  384: 'holding_hands',
#  385: 'facial_hair',
#  386: 'chain',
#  387: 'headgear',
#  388: 'bird',
#  389: 'pov',
#  390: 'siblings',
#  391: 'headphones',
#  392: 'ocean',
#  393: '6+girls',
#  394: 'low_twintails',
#  395: 'heterochromia',
#  396: 'arm_support',
#  397: 'animal',
#  398: 'halterneck',
#  399: 'frown',
#  400: 'leaf',
#  401: 'beret',
#  402: 'white_headwear',
#  403: 'umbrella',
#  404: 'on_bed',
#  405: 'one_side_up',
#  406: 'embarrassed',
#  407: 'thigh_boots',
#  408: 'fangs',
#  409: 'upper_teeth_only',
#  410: 'watermark',
#  411: 'from_above',
#  412: 'back',
#  413: 'highleg',
#  414: 'blue_background',
#  415: 'ass_visible_through_thighs',
#  416: 'wavy_hair',
#  417: 'garter_straps',
#  418: 'black_choker',
#  419: 'halo',
#  420: 'blue_bow',
#  421: 'scar',
#  422: 'white_bikini',
#  423: 'on_side',
#  424: 'plaid_skirt',
#  425: 'chair',
#  426: 'transparent_background',
#  427: 'wariza',
#  428: 'facial_mark',
#  429: 'mouth_hold',
#  430: 'looking_away',
#  431: 'traditional_media',
#  432: 'beach',
#  433: 'bandages',
#  434: 'parody',
#  435: 'female_pubic_hair',
#  436: 'expressionless',
#  437: 'brown_footwear',
#  438: 'blush_stickers',
#  439: 'shirt_lift',
#  440: 'thick_thighs',
#  441: 'no_shoes',
#  442: 'holding_sword',
#  443: 'hair_tubes',
#  444: 'chinese_clothes',
#  445: 'drill_hair',
#  446: 'grabbing',
#  447: 'arms_behind_back',
#  448: 'soles',
#  449: 'obi',
#  450: 'heart-shaped_pupils',
#  451: 'eating',
#  452: 'clothes_pull',
#  453: 'looking_down',
#  454: 'phone',
#  455: 'black_shorts',
#  456: 'thigh_gap',
#  457: 'black_pants',
#  458: 'short_dress',
#  459: 'topless',
#  460: 'piercing',
#  461: 'pantyshot',
#  462: 'hair_intakes',
#  463: 'eyepatch',
#  464: 'border',
#  465: 'skirt_lift',
#  466: 'floral_print',
#  467: 'stuffed_toy',
#  468: 'bound',
#  469: 'formal',
#  470: 'playboy_bunny',
#  471: 'flying_sweatdrops',
#  472: 'crossed_arms',
#  473: 'wavy_mouth',
#  474: 'magical_girl',
#  475: 'erection',
#  476: 'abs',
#  477: 'moon',
#  478: 'half-closed_eyes',
#  479: 'leg_up',
#  480: 'from_below',
#  481: 'red_dress',
#  482: 'cleavage_cutout',
#  483: 'sandals',
#  484: 'table',
#  485: 'happy',
#  486: 'sunlight',
#  487: 'oral',
#  488: 'cover',
#  489: 'squatting',
#  490: 'single_hair_bun',
#  491: 'cat',
#  492: 'testicles',
#  493: 'pink_background',
#  494: 'sunglasses',
#  495: 'scrunchie',
#  496: 'white_footwear',
#  497: 'dark-skinned_male',
#  498: 'underwear_only',
#  499: 'cum_on_body',
#  500: 'trembling',
#  501: 'bob_cut',
#  502: 'ring',
#  503: 'bdsm',
#  504: 'school_swimsuit',
#  505: 'mob_cap',
#  506: 'wolf_ears',
#  507: 'blazer',
#  508: 'light_brown_hair',
#  509: 'white_jacket',
#  510: 'standing_on_one_leg',
#  511: 'sleeping',
#  512: 'thick_eyebrows',
#  513: 'backpack',
#  514: 'white_skirt',
#  515: 'demon_girl',
#  516: 'frilled_dress',
#  517: 'eyes_visible_through_hair',
#  518: 'breast_grab',
#  519: 'cardigan',
#  520: 'knee_boots',
#  521: 'suspenders',
#  522: 'hat_ribbon',
#  523: 'crossed_legs',
#  524: 'lingerie',
#  525: 'stuffed_animal',
#  526: 'katana',
#  527: 'hood_down',
#  528: ';d',
#  529: '3boys',
#  530: 'bat_wings',
#  531: 'horse_ears',
#  532: 'helmet',
#  533: 'cloudy_sky',
#  534: 'cellphone',
#  535: 'crying',
#  536: 'antenna_hair',
#  537: 'own_hands_together',
#  538: 'tank_top',
#  539: 'bottle',
#  540: 'suit',
#  541: 'grass',
#  542: 'outstretched_arms',
#  543: 'cross',
#  544: 'bug',
#  545: 'holding_food',
#  546: 'fire',
#  547: 'frilled_skirt',
#  548: 'tiara',
#  549: 'aged_down',
#  550: 'polka_dot',
#  551: 'feathers',
#  552: 'breasts_out',
#  553: 'crossover',
#  554: 'crown',
#  555: 'high_ponytail',
#  556: 'looking_up',
#  557: 'black_hairband',
#  558: 'bent_over',
#  559: 'undressing',
#  560: 'blue_shirt',
#  561: 'white_bow',
#  562: '5girls',
#  563: 'straddling',
#  564: 'light_smile',
#  565: 'knife',
#  566: 'pectorals',
#  567: 'x_hair_ornament',
#  568: 'plant',
#  569: 'couple',
#  570: 'denim',
#  571: 'on_stomach',
#  572: 'wing_collar',
#  573: '>_<',
#  574: 'robot',
#  575: 'white_flower',
#  576: 'hair_bobbles',
#  577: 'fellatio',
#  578: 'outstretched_arm',
#  579: 'sharp_teeth',
#  580: 'blue_ribbon',
#  581: 'lipstick',
#  582: 'tan',
#  583: 'girl_on_top',
#  584: 'cat_girl',
#  585: 'short_twintails',
#  586: 'lifted_by_self',
#  587: 'bondage',
#  588: 'curtains',
#  589: 'white_socks',
#  590: 'letterboxed',
#  591: 'animal_print',
#  592: 'muscular_male',
#  593: 'spiked_hair',
#  594: 'pointing',
#  595: 'pink_bow',
#  596: 'juliet_sleeves',
#  597: 'monster_girl',
#  598: 'sex_from_behind',
#  599: 'slit_pupils',
#  600: 'polearm',
#  601: 'all_fours',
#  602: 'blue_jacket',
#  603: 'sisters',
#  604: '^^^',
#  605: 'frilled_sleeves',
#  606: 'hand_on_own_chest',
#  607: 'red_necktie',
#  608: 'blue_sailor_collar',
#  609: 'crescent',
#  610: '?',
#  611: 'staff',
#  612: 'black_background',
#  613: 'clenched_teeth',
#  614: 'panty_pull',
#  615: 'cherry_blossoms',
#  616: 'head_wings',
#  617: 'horse_girl',
#  618: 'brooch',
#  619: 'goggles',
#  620: 'demon_horns',
#  621: 'towel',
#  622: 'blouse',
#  623: 'shaded_face',
#  624: 'red_flower',
#  625: 'green_skirt',
#  626: 'fox_girl',
#  627: 'ground_vehicle',
#  628: 'cover_page',
#  629: 'black_bra',
#  630: 'elf',
#  631: 'bike_shorts',
#  632: 'otoko_no_ko',
#  633: 'wind',
#  634: 'casual',
#  635: 'black_socks',
#  636: 'loafers',
#  637: 't-shirt',
#  638: 'motion_lines',
#  639: 'shoulder_armor',
#  640: 'gauntlets',
#  641: 'no_pants',
#  642: 'building',
#  643: 'pink_panties',
#  644: 'messy_hair',
#  645: 'single_thighhigh',
#  646: 'multiple_tails',
#  647: 'kiss',
#  648: 'wristband',
#  649: 'group_sex',
#  650: 'breast_press',
#  651: 'between_breasts',
#  652: 'surprised',
#  653: 'striped_panties',
#  654: 'hat_bow',
#  655: 'gem',
#  656: 'butterfly',
#  657: 'red_footwear',
#  658: 'red_shirt',
#  659: 'sheath',
#  660: 'sneakers',
#  661: 'rabbit_tail',
#  662: 'tassel',
#  663: 'instrument',
#  664: 'box',
#  665: 'ear_piercing',
#  666: 'drooling',
#  667: 'fishnets',
#  668: 'ribbon_trim',
#  669: 'clenched_hand',
#  670: 'sex_toy',
#  671: 'red_bowtie',
#  672: 'third_eye',
#  673: 'skirt_set',
#  674: 'child',
#  675: 'hakama',
#  676: 'pale_skin',
#  677: 'portrait',
#  678: 'musical_note',
#  679: 'revealing_clothes',
#  680: 'rope',
#  681: 'star_(sky)',
#  682: 'wet_clothes',
#  683: 'steam',
#  684: 'candy',
#  685: 'pink_dress',
#  686: 'genderswap',
#  687: 'facial',
#  688: 'demon_tail',
#  689: 'dog_ears',
#  690: 'anal',
#  691: 'foreshortening',
#  692: 'holding_gun',
#  693: 'nature',
#  694: 'covering',
#  695: 'adapted_costume',
#  696: 'side-tie_panties',
#  697: 'black_nails',
#  698: 'night_sky',
#  699: 'christmas',
#  700: 'breath',
#  701: 'ejaculation',
#  702: 'veil',
#  703: 'scenery',
#  704: 'armband',
#  705: 'peaked_cap',
#  706: 'waist_apron',
#  707: 'lace_trim',
#  708: 'convenient_censoring',
#  709: 'white_apron',
#  710: 'couch',
#  711: 'arms_behind_head',
#  712: 'china_dress',
#  713: 'bandaid',
#  714: 'holding_cup',
#  715: 'black_leotard',
#  716: 'male_pubic_hair',
#  717: 'interlocked_fingers',
#  718: 'mole_under_mouth',
#  719: 'microphone',
#  720: 'bridal_gauntlets',
#  721: 'bara',
#  722: 'strapless_dress',
#  723: 'tokin_hat',
#  724: 'yaoi',
#  725: 'straight_hair',
#  726: 'front-tie_top',
#  727: 'bow_panties',
#  728: 'lace',
#  729: 'mecha',
#  730: 'hakama_skirt',
#  731: 'hand_fan',
#  732: 'white_ribbon',
#  733: 'glowing_eyes',
#  734: 'anger_vein',
#  735: '...',
#  736: 'breasts_apart',
#  737: 'no_headwear',
#  738: 'hair_over_shoulder',
#  739: 'clothes_writing',
#  740: 'jingle_bell',
#  741: 'baseball_cap',
#  742: 'yellow_background',
#  743: 'hair_flaps',
#  744: 'string_bikini',
#  745: 'feathered_wings',
#  746: 'hooded_jacket',
#  747: 'cum_on_breasts',
#  748: 'bikini_top_only',
#  749: 'red_headwear',
#  750: 'twin_drills',
#  751: 'facing_viewer',
#  752: 'skin_tight',
#  753: 'multiple_penises',
#  754: 'semi-rimless_eyewear',
#  755: 'red_nails',
#  756: 'bright_pupils',
#  757: 'black_necktie',
#  758: 'web_address',
#  759: ':<',
#  760: 'angry',
#  761: 'grey_shirt',
#  762: 'cloak',
#  763: 'eyewear_on_head',
#  764: 'motor_vehicle',
#  765: 'red_background',
#  766: 'claws',
#  767: 'side_braid',
#  768: 'wolf_tail',
#  769: 'pelvic_curtain',
#  770: 'light_particles',
#  771: 'light_purple_hair',
#  772: 'multicolored_clothes',
#  773: 'carrying',
#  774: 'micro_bikini',
#  775: 'knees_up',
#  776: 'smartphone',
#  777: 'corset',
#  778: 'tentacles',
#  779: 'index_finger_raised',
#  780: 'clothing_aside',
#  781: 'purple_dress',
#  782: 'extra_ears',
#  783: 'rifle',
#  784: 'striped_thighhighs',
#  785: 'white_border',
#  786: 'mary_janes',
#  787: 'beard',
#  788: 'paizuri',
#  789: 'vertical_stripes',
#  790: 'red_jacket',
#  791: ':p',
#  792: 'red_neckerchief',
#  793: 'short_hair_with_long_locks',
#  794: 'scar_on_face',
#  795: 'tareme',
#  796: 'neck_bell',
#  797: 'licking',
#  798: 'furry',
#  799: 'single_horn',
#  800: 'strap_slip',
#  801: 'finger_to_mouth',
#  802: 'pom_pom_(clothes)',
#  803: 'snow',
#  804: 'french_braid',
#  805: 'close-up',
#  806: 'androgynous',
#  807: '1other',
#  808: 'areola_slip',
#  809: 'forehead',
#  810: 'puffy_nipples',
#  811: 'buckle',
#  812: 'horse_tail',
#  813: 'two-tone_background',
#  814: 'full_moon',
#  815: 'eye_contact',
#  816: 'pink_flower',
#  817: 'tsurime',
#  818: 'yellow_bow',
#  819: 'gift',
#  820: 'seiza',
#  821: 'upskirt',
#  822: 'blue_bikini',
#  823: 'pink_nails',
#  824: 'santa_hat',
#  825: 'genderswap_(mtf)',
#  826: 'lens_flare',
#  827: 'skin_fang',
#  828: 'spikes',
#  829: 'armlet',
#  830: 'hand_on_own_face',
#  831: 'desk',
#  832: 'between_legs',
#  833: 'brown_gloves',
#  834: 'side_slit',
#  835: 'handgun',
#  836: 'camisole',
#  837: 'wading',
#  838: 'faceless',
#  839: 'low_ponytail',
#  840: 'restrained',
#  841: 'pendant',
#  842: 'plate',
#  843: 'dual_persona',
#  844: 'masturbation',
#  845: 'highleg_leotard',
#  846: 'spoken_heart',
#  847: 'curvy',
#  848: 'green_bow',
#  849: 'maid_apron',
#  850: 'alcohol',
#  851: 'after_sex',
#  852: 'grey_skirt',
#  853: 'handjob',
#  854: 'sleeves_rolled_up',
#  855: 'red_gloves',
#  856: 'o-ring',
#  857: 'heavy_breathing',
#  858: 'abyssal_ship',
#  859: 'eyeshadow',
#  860: 'ribbed_sweater',
#  861: 'drinking_glass',
#  862: 'hair_scrunchie',
#  863: 'cowgirl_position',
#  864: 'cross-laced_footwear',
#  865: 'blue_headwear',
#  866: 'broom',
#  867: 'ball',
#  868: 'puffy_long_sleeves',
#  869: 'sleeves_past_fingers',
#  870: 'clenched_hands',
#  871: 'hood_up',
#  872: 'cropped_legs',
#  873: 'floating',
#  874: 'wide_hips',
#  875: 'forest',
#  876: 'low-tied_long_hair',
#  877: 'breast_hold',
#  878: 'smoke',
#  879: 'zipper',
#  880: 'dress_lift',
#  881: 'tray',
#  882: 'personification',
#  883: 'headwear_removed',
#  884: 'high_heel_boots',
#  885: 'partially_submerged',
#  886: 'headset',
#  887: 'halloween',
#  888: 'hair_rings',
#  889: 'legs_up',
#  890: 'half_updo',
#  891: 'doujin_cover',
#  892: 'pink_skirt',
#  893: 'starry_sky',
#  894: 'colored_sclera',
#  895: 'pencil_skirt',
#  896: 'strapless_leotard',
#  897: 'single_glove',
#  898: 'machinery',
#  899: 'clothed_sex',
#  900: 'blue_nails',
#  901: 'backlighting',
#  902: 'freckles',
#  903: 'tearing_up',
#  904: 'reflection',
#  905: 'tanlines',
#  906: 'fish',
#  907: 'sweater_vest',
#  908: 'holding_book',
#  909: 'arm_behind_back',
#  910: 'arm_at_side',
#  911: 'santa_costume',
#  912: 'large_pectorals',
#  913: 'spot_color',
#  914: 'flying',
#  915: 'white_bra',
#  916: 'asymmetrical_legwear',
#  917: 'brown_background',
#  918: 'panties_under_pantyhose',
#  919: 'nontraditional_miko',
#  920: 'red_bikini',
#  921: 'happy_birthday',
#  922: 'cropped_jacket',
#  923: 'long_fingernails',
#  924: '!',
#  925: 'kemonomimi_mode',
#  926: 'sailor_dress',
#  927: 'clothed_female_nude_male',
#  928: 'walking',
#  929: 'fingering',
#  930: 'science_fiction',
#  931: 'rain',
#  932: 'white_pantyhose',
#  933: 'garter_belt',
#  934: 'frilled_bikini',
#  935: 'dual_wielding',
#  936: '6+boys',
#  937: 'pink_ribbon',
#  938: 'cuffs',
#  939: 'red-framed_eyewear',
#  940: 'dragon_horns',
#  941: 'epaulettes',
#  942: 'black_wings',
#  943: 'bubble',
#  944: 'demon_wings',
#  945: 'thong',
#  946: 'legs_apart',
#  947: 'teacup',
#  948: 'condom',
#  949: 'veins',
#  950: 'crossdressing',
#  951: 'ribbon-trimmed_sleeves',
#  952: 'holding_phone',
#  953: 'gym_uniform',
#  954: 'short_ponytail',
#  955: 'arm_behind_head',
#  956: 'cake',
#  957: 'out_of_frame',
#  958: 'innertube',
#  959: 'oni_horns',
#  960: 'contrapposto',
#  961: 'naughty_face',
#  962: 'green_background',
#  963: 'alternate_breast_size',
#  964: 'purple_background',
#  965: 'black-framed_eyewear',
#  966: 'rape',
#  967: 'beads',
#  968: 'knee_up',
#  969: 'hat_ornament',
#  970: 'one-hour_drawing_challenge',
#  971: 'fur_collar',
#  972: 'blue_shorts',
#  973: 'outside_border',
#  974: 'thighband_pantyhose',
#  975: 'meme',
#  976: 'bowl',
#  977: 'toenails',
#  978: 'cumdrip',
#  979: 'blue_flower',
#  980: 'denim_shorts',
#  981: 'curly_hair',
#  982: 'track_jacket',
#  983: 'black_sailor_collar',
#  984: 'light_blush',
#  985: 'school_bag',
#  986: 'pocket',
#  987: 'spread_pussy',
#  988: 'toned',
#  989: 'pink_shirt',
#  990: 'doggystyle',
#  991: 'white_sleeves',
#  992: ':q',
#  993: 'hand_in_own_hair',
#  994: 'spoken_ellipsis',
#  995: 'empty_eyes',
#  996: 'purple_skirt',
#  997: 'crying_with_eyes_open',
#  998: 'goggles_on_head',
#  999: 'green_dress',
#  ...}

# %%
config.id2label = id2label
config.label2id = {v: k for k, v in id2label.items()}

# %%
config.save_pretrained("tagger-hf")

# %% [markdown]
# ## Create hf SwinV2 model

# %%
swinv2 = Swinv2ForImageClassification._from_config(config)

# %% [markdown]
# ## Load keras model

# %%
model: Model = load_model("tagger")

# %%
for layer in model.layers:
    print(layer.name, layer.input_shape)
# Out:
# input_1 [(None, 448, 448, 3)]
# tf.cast (None, 448, 448, 3)
# tf.math.subtract (None, 448, 448, 3)
# tf.math.multiply (None, 448, 448, 3)
# conv2d (None, 448, 448, 3)
# reshape (None, 112, 112, 128)
# layer_normalization (None, 12544, 128)
# dropout (None, 12544, 128)
# swin_transformer_block (None, 12544, 128)
# swin_transformer_block_1 (None, 12544, 128)
# patch_merging (None, 12544, 128)
# swin_transformer_block_2 (None, 3136, 256)
# swin_transformer_block_3 (None, 3136, 256)
# patch_merging_1 (None, 3136, 256)
# swin_transformer_block_4 (None, 784, 512)
# swin_transformer_block_5 (None, 784, 512)
# swin_transformer_block_6 (None, 784, 512)
# swin_transformer_block_7 (None, 784, 512)
# swin_transformer_block_8 (None, 784, 512)
# swin_transformer_block_9 (None, 784, 512)
# swin_transformer_block_10 (None, 784, 512)
# swin_transformer_block_11 (None, 784, 512)
# swin_transformer_block_12 (None, 784, 512)
# swin_transformer_block_13 (None, 784, 512)
# swin_transformer_block_14 (None, 784, 512)
# swin_transformer_block_15 (None, 784, 512)
# swin_transformer_block_16 (None, 784, 512)
# swin_transformer_block_17 (None, 784, 512)
# swin_transformer_block_18 (None, 784, 512)
# swin_transformer_block_19 (None, 784, 512)
# swin_transformer_block_20 (None, 784, 512)
# swin_transformer_block_21 (None, 784, 512)
# patch_merging_2 (None, 784, 512)
# swin_transformer_block_22 (None, 196, 1024)
# swin_transformer_block_23 (None, 196, 1024)
# predictions_norm (None, 196, 1024)
# predictions_globalavgpooling (None, 196, 1024)
# predictions_dense (None, 1024)
# predictions_sigmoid (None, 9083)

# %% [markdown]
# References:
#
# - https://github.com/SmilingWolf/SW-CV-ModelZoo/blob/main/Models/SwinV2.py
# - https://github.com/huggingface/transformers/blob/v4.37.2/src/transformers/models/swinv2/modeling_swinv2.py

# %% [markdown]
# ### utils

# %%
def convert_conv2d(array: np.ndarray):
    return nn.Parameter(
        torch.from_numpy(
            array,
        )
        .permute(3, 2, 0, 1)
        .contiguous()  # fix shape
    )


def convert_dense(array: np.ndarray):
    return nn.Parameter(
        torch.from_numpy(
            array,
        )
        .transpose(1, 0)
        .contiguous()  # fix shape
    )


def convert_tensor(array: np.ndarray):
    return nn.Parameter(torch.from_numpy(array).contiguous())

# %%
def get_weight(name: str, index: int = 0):
    return model.get_layer(name).weights[index].numpy()

# %% [markdown]
# ## Swinv2Embeddings

# %%
swinv2.swinv2.embeddings.patch_embeddings.projection.weight = convert_conv2d(
    get_weight("conv2d", 0),  # 0 means weight
)
swinv2.swinv2.embeddings.patch_embeddings.projection.bias = convert_tensor(
    get_weight("conv2d", 1),  # 1 means bias
)

# %%
swinv2.swinv2.embeddings.norm.weight = convert_tensor(
    get_weight("layer_normalization", 0),
)
swinv2.swinv2.embeddings.norm.bias = convert_tensor(
    get_weight("layer_normalization", 1),
)

# %% [markdown]
# ## Swinv2Encoder

# %% [markdown]
# swin_transformer_block has
#
# - `norm1`
# - `attn`
#   - `cpb_mlp`
#     - 0: `cpb_mlp/dense_0`
#     - 1: cpb_mlp/relu
#     - 2: `cpb_mlp_dense_1`
#   - `qkv`
#   - attn_drop
#   - `proj`
#   - proj_drop
#   - softmax
# - drop_path
# - `norm2`
# - `mlp`
#   - `fc1`
#   - act: gelu
#   - `fc2`
#   - drop

# %%
layer_num = 0

block_num = lambda x: f"_{x}" if x > 0 else ""

for i_layer, dim in enumerate(config.depths):
    for i_dim in range(dim):
        # print(i_layer, i_dim)
        block_name = f"swin_transformer_block{block_num(layer_num)}"

        swinv2_block = swinv2.swinv2.encoder.layers[i_layer].blocks[i_dim]

        # norm1
        swinv2_block.layernorm_before.weight = convert_tensor(
            model.get_layer(block_name).norm1.weights[0].numpy()
        )
        swinv2_block.layernorm_before.bias = convert_tensor(
            model.get_layer(block_name).norm1.weights[1].numpy()
        )

        # attn/cpb_mlp
        for i, layer in enumerate(model.get_layer(block_name).attn.cpb_mlp.layers):
            if i == 0 or i == 2:  # dense
                # print(layer.weights[0].numpy().shape)
                # print(swinv2_block.attention.self.continuous_position_bias_mlp)
                swinv2_block.attention.self.continuous_position_bias_mlp[i].weight = (
                    convert_dense(layer.weights[0].numpy())
                )
                if i == 0:
                    # the second dense doesn't have bias
                    swinv2_block.attention.self.continuous_position_bias_mlp[i].bias = (
                        convert_tensor(layer.weights[1].numpy())
                    )

        # print(model.get_layer(block_name).attn.qkv.weights[0].numpy().shape)

        # attn/qkv
        [
            swinv2_block.attention.self.query.weight,
            swinv2_block.attention.self.key.weight,
            swinv2_block.attention.self.value.weight,
        ] = [
            convert_dense(array)
            for array in np.split(
                model.get_layer(block_name).attn.qkv.weights[0].numpy(), 3, axis=1
            )
        ]
        swinv2_block.attention.self.query.bias = convert_tensor(
            model.get_layer(block_name).attn.q_bias.numpy()
        )
        swinv2_block.attention.self.value.bias = convert_tensor(
            model.get_layer(block_name).attn.v_bias.numpy()
        )

        # proj (output.dense)
        swinv2_block.attention.output.dense.weight = convert_dense(
            model.get_layer(block_name).attn.proj.weights[0].numpy()
        )
        swinv2_block.attention.output.dense.bias = convert_tensor(
            model.get_layer(block_name).attn.proj.weights[1].numpy()
        )

        # print(swinv2.swinv2.encoder.layers[i_layer].blocks[i_dim].attention.self)

        # norm2
        swinv2_block.layernorm_after.weight = convert_tensor(
            model.get_layer(block_name).norm2.weights[0].numpy()
        )
        swinv2_block.layernorm_after.bias = convert_tensor(
            model.get_layer(block_name).norm2.weights[1].numpy()
        )

        # mlp
        # -> Swinv2Intermediate and Swinv2Output (dense, activation, dense, dropout)
        swinv2_block.intermediate.dense.weight = convert_dense(
            model.get_layer(block_name).mlp.fc1.weights[0].numpy()
        )
        swinv2_block.intermediate.dense.bias = convert_tensor(
            model.get_layer(block_name).mlp.fc1.weights[1].numpy()
        )

        swinv2_block.output.dense.weight = convert_dense(
            model.get_layer(block_name).mlp.fc2.weights[0].numpy()
        )
        swinv2_block.output.dense.bias = convert_tensor(
            model.get_layer(block_name).mlp.fc2.weights[1].numpy()
        )

        layer_num += 1

# %% [markdown]
# ### Patch merging

# %%
layer_num = 0

block_num = lambda x: f"_{x}" if x > 0 else ""

for i_layer, dim in enumerate(config.depths):
    if i_layer < len(config.depths) - 1:
        swinv2_block = swinv2.swinv2.encoder.layers[i_layer]
        block_name = f"patch_merging{block_num(layer_num)}"

        # reduction
        swinv2_block.downsample.reduction.weight = convert_dense(
            get_weight(block_name, 0)
        )

        # norm
        swinv2_block.downsample.norm.weight = convert_tensor(
            model.get_layer(block_name).norm.weights[0].numpy()
        )
        swinv2_block.downsample.norm.bias = convert_tensor(
            model.get_layer(block_name).norm.weights[1].numpy()
        )

    layer_num += 1

# %% [markdown]
# ## LayerNorm

# %%
swinv2.swinv2.layernorm.weight = convert_tensor(get_weight("predictions_norm", 0))
swinv2.swinv2.layernorm.bias = convert_tensor(get_weight("predictions_norm", 1))

# %% [markdown]
# ## classifier

# %%
swinv2.classifier.weight = convert_dense(get_weight("predictions_dense", 0))
swinv2.classifier.bias = convert_tensor(get_weight("predictions_dense", 1))

# %% [markdown]
# ## Save model

# %%
swinv2.save_pretrained("./tagger-hf")
